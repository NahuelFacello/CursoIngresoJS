# %% [markdown]
# <a href="https://colab.research.google.com/github/NahuelFacello/CursoIngresoJS/blob/master/Text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')

import gtts
from IPython.display import Audio

texto = "Hola Mundo, este es un ejemplo de sintesis de voz con gtts."

tts = gtts.gTTS(texto, lang='es')

tts.save("audio.mp3")

Audio("audio.mp3")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
